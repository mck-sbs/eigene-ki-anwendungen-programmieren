# %%
from google import genai

API_KEY = "..."

# %%
msg = "Lebst du?"

client = genai.Client(api_key=API_KEY)

response = client.models.generate_content(model="gemini-2.0-flash", contents=msg)
print(response.text)
# Out:
# Als großes Sprachmodell bin ich ein Computerprogramm, keine lebende Person. Ich habe kein Bewusstsein oder Gefühle.
