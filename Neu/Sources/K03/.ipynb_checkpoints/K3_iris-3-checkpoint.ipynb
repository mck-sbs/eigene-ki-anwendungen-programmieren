# %% [markdown]
# Benötigte Module importieren und Datei laden. Die ersten Zeilen werden ausgegeben.

# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split

path = "../Data/iris_empty.csv"
data = pd.read_csv(path, delimiter=',')

print(data.head())
print("Empty columns: ", data.columns[data.isnull().any()])
# Out:
#    sepal.length  sepal.width  petal.length  petal.width species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# Empty columns:  Index(['sepal.length', 'petal.length', 'species'], dtype='object')

# %% [markdown]
# Daten vorbereiten.

# %%
# Leere Zellen mit Mittelwerten der Spalten füllen
data['sepal.length'] = data['sepal.length'].fillna(data['sepal.length'].mean())
data['petal.length'] = data['petal.length'].fillna(data['petal.length'].mean())
data['species'] = data['species'].fillna("empty")

# Was soll vorhergesagt werden? Spaltenname in Variable speichern.
col_name = 'species'

# Zeichenkette in OHE umwandeln, Ergebniss in neuer Tabelle
col = pd.get_dummies(data[col_name], dtype=float)

# Aus der ursprünglichen Tabelle werden die species entfernt,  Ergbnisse in neuer Tabelle
data = data.drop([col_name], axis = 1)
#Somit zwei Tabellen vorhanden

# %% [markdown]
# KNN aufbauen

# %%
# Aus den zwei Tabellen vier Tabellen erzeugen
train_data, test_data, train_col, test_col = train_test_split(data,col, test_size=0.2, random_state=42)

# Aufbau KNN
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(4,)))
model.add(tf.keras.layers.Dense(32, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(64, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(4, activation=tf.nn.softmax))
# Konfiguration des Lernprozesses
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Trainieren

# %%
# 50 Durchläufe
model.fit(train_data, train_col, epochs=50)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3248 - loss: 1.3888
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3227 - loss: 1.2737
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2956 - loss: 1.2183
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3331 - loss: 1.1871
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3429 - loss: 1.1481
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3346 - loss: 1.1485
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5002 - loss: 1.1292
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5527 - loss: 1.1499
# Epoch 9/50
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6250 - loss: 1.1035

# %% [markdown]
# Testen

# %%
test_loss, test_acc = model.evaluate(test_data, test_col)
print('Test accuracy:', test_acc)
