# %% [markdown]
# Benötigte Module importieren und Datei laden. Die ersten Zeilen werden ausgegeben.

# %%
import pandas as pd
import tensorflow as tf
from keras.models import Model
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Modell laden

# %%
model = tf.keras.models.load_model('K6-transfer.h5', compile=False)
# Out:
# 2023-06-07 17:37:43.429584: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Achtung, Pfad aktualisieren
file = "../../Data/horse.png"

img = tf.keras.utils.load_img(file,target_size=(300, 300,3))
img = np.array(img)

plt.figure()
plt.imshow(img)
plt.show()

# %%
class_names = ['horse', 'human']

img = tf.keras.applications.vgg19.preprocess_input(img)

pred = model.predict(img.reshape(1, 300, 300, 3))

print("prediction softmax:",pred)
print("prediction max:",pred.argmax())
print("prediction string:",class_names[pred.argmax()])
# Out:
# 1/1 [==============================] - 0s 223ms/step
# prediction softmax: [[1.3420883e-24 1.0000000e+00]]
# prediction max: 1
# prediction string: human
